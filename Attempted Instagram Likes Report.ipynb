# %%
import pandas as pd
import json

# %%
with open(r"C:\Users\footb\Data Fa22\rebeccah189_20220906\likes\liked_posts.json") as j:
    liked_posts = json.load(j)

# %%
liked_posts_df= pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6], 'c': [7, 8, 9]})

# %%
liked_posts_df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
liked_posts_df2 = pd.DataFrame([{'a': 1, 'b': 4, 'c':7}, {'a': 2, 'b':5, 'c':8}, {'a': 3, 'b': 6, 'c':9}])

# %%
liked_posts_df2
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
liked_posts
# Out:
# {'likes_media_likes': [{'title': 'therealcarl0spena',
#    'media_list_data': [],
#    'string_list_data': [{'href': 'https://www.instagram.com/p/poQC9rP6uN/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1403618902}]},
#   {'title': 'godsholyscriptures',
#    'media_list_data': [],
#    'string_list_data': [{'href': 'https://www.instagram.com/p/pm0kjByii5/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1403574102}]},
#   {'title': 'ashley_phillips_97',
#    'media_list_data': [],
#    'string_list_data': [{'href': 'https://www.instagram.com/p/pm5mgciGf4X2lHiqR4ZmYeFpn5DwRIl8gVyV40/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1403573869}]},
#   {'title': 'chancehooper1224',
#    'media_list_data': [],
#    'string_list_data': [{'href': 'https://www.instagram.com/p/pm6EV-JxQBdNJoAnliqZU2-kENaKpuzgb40nA0/',
#      'value': 'ð\x9f\x91\x8d',
#      'timestamp': 1403572477}]},
#   {'title': 'chancehooper1224',
#    'media_list_data': [],
# ...

# %%
test1 = pd.DataFrame(liked_posts)

# %%
test1.head()
# Out:
#                                    likes_media_likes
# 0  {'title': 'therealcarl0spena', 'media_list_dat...
# 1  {'title': 'godsholyscriptures', 'media_list_da...
# 2  {'title': 'ashley_phillips_97', 'media_list_da...
# 3  {'title': 'chancehooper1224', 'media_list_data...
# 4  {'title': 'chancehooper1224', 'media_list_data...

# %%
test2 = pd.DataFrame(liked_posts['likes_media_likes'])

# %%
test2.head()
# Out:
#                 title media_list_data  \
# 0   therealcarl0spena              []
# 1  godsholyscriptures              []
# 2  ashley_phillips_97              []
# 3    chancehooper1224              []
# 4    chancehooper1224              []
#
#                                     string_list_data
# 0  [{'href': 'https://www.instagram.com/p/poQC9rP...
# 1  [{'href': 'https://www.instagram.com/p/pm0kjBy...
# 2  [{'href': 'https://www.instagram.com/p/pm5mgci...
# 3  [{'href': 'https://www.instagram.com/p/pm6EV-J...
# 4  [{'href': 'https://www.instagram.com/p/pms9ONJ...

# %%
test2['string_list_data'][0]
# Out:
# [{'href': 'https://www.instagram.com/p/poQC9rP6uN/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1403618902}]

# %%
test2['string_list_data'][0][0]
# Out:
# {'href': 'https://www.instagram.com/p/poQC9rP6uN/',
#  'value': 'ð\x9f\x91\x8d',
#  'timestamp': 1403618902}

# %%
test2.head()
# Out:
#                 title media_list_data  \
# 0   therealcarl0spena              []
# 1  godsholyscriptures              []
# 2  ashley_phillips_97              []
# 3    chancehooper1224              []
# 4    chancehooper1224              []
#
#                                     string_list_data
# 0  [{'href': 'https://www.instagram.com/p/poQC9rP...
# 1  [{'href': 'https://www.instagram.com/p/pm0kjBy...
# 2  [{'href': 'https://www.instagram.com/p/pm5mgci...
# 3  [{'href': 'https://www.instagram.com/p/pm6EV-J...
# 4  [{'href': 'https://www.instagram.com/p/pms9ONJ...

# %% [markdown]
# ### Dear Dr. Silva, I completely understand that this Instagram report is not what you wanted and that it does not fulfill the requirements of this project. I struggled significantly with trying to pull data out within strings. I am confused as to why under my media_list_data, it is listed as empty. I tried to pull data from it and there was nothing.

# %%
test2['media_list_data'][0]
# Out:
# []

# %% [markdown]
# #### The list is empty and it is quite confusing to me. I was hoping it would be listed in such a way that would mirror your facebook data example. I know the code is different, however the concept is the same if I understand this correctly. I then decided to keep on following your example and go a step further to get rid of the brackets so we're able to pull data from the string.

# %%
test2['media_list_data'][0][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [56], in <cell line: 1>()
# ----> 1 test2['media_list_data'][0][0]
#
# IndexError: list index out of range

# %% [markdown]
# ##### However, when I did that it says that the list index is out of range. I am not sure what this means. I decided to keep trying to figure out what was going on and decided to try something different.

# %%
test2['media_list_data'][[]]
# Out:
# Series([], Name: media_list_data, dtype: object)

# %% [markdown]
# ###### This popped up and I was confused as to exactly what this means and what to do from here.

# %% [markdown]
# ###### I decided from here to pause on this data and to instead, show my skills and effort with my Facebook data. I completely understand it was not apart of the assignment, however I still wanted to show you that I understand how to read parts of my data as well as use the code. Unfortunately, time got the best of me and I now have learned for future projects to be sure I understand the code specifically as well as the other assignment components before it is due. I truly apologize for this.
