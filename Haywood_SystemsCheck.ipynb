# %% [markdown]
# # Systems Check Assignment
# ## Rebecca Haywood

# %% [markdown]
# ### Things I am excited about for this class
# 1. ***I am excited about learning how to understand the data of my Spotify***
# 2. I am looking forward to understanding the behind the scenes of my social medias
# 3. Be able to use this information I use in class in my future career(s)

# %% [markdown]
# #### A little about me
# - I love dogs
# - I have a passion of working with individuals with disabilities and bettering their lives
# - I have a dog named Rosey
# - I am an EMAT major with minors in: User Experience Design and Autism Spectrum Disorders

# %% [markdown]
# ##### Thank you for your help on Monday!

# %% [markdown]
# [Link to Google](https://www.Google.com)

# %% [markdown]
# ![RoseyBirthday.jpg](attachment:RoseyBirthday.jpg)
